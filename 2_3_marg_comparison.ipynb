# %% [markdown]
# Compare the versions with and without marginalisation.

# %%
from utilities_single_reg import *

# %%
xdet, ydet, xdet_err, ydet_err, xuplim, yuplim, xuplim_err, yuplim_err , true_params = gen_synthetic_data()
# Out:
# Number of uplims:  43
# True mu: -0.26670460907759524
# True w: 1.3956861244670145
# True line: y = 0.6120x + 0.1200, sigma = 0.5000

# %%
# One run 
print("Our method:")
run_linear_regression_marginalised_xt(i=0, plot=True)
# Out:
# Our method:
# ...
# sample: 100%|██████████| 6000/6000 [00:10<00:00, 599.91it/s, 7 steps of size 6.19e-01. acc. prob=0.93]
#                 mean       std    median      5.0%     95.0%     n_eff     r_hat
#          A      0.67      0.05      0.67      0.60      0.76   1171.79      1.00
#          B      0.06      0.06      0.06     -0.03      0.16   1597.09      1.00
#   mu_gauss     -0.43      0.12     -0.43     -0.61     -0.22   1394.03      1.00
#        sig      0.51      0.04      0.51      0.45      0.59   1544.54      1.00
#    w_gauss      1.22      0.09      1.22      1.07      1.36   1259.83      1.00
#
# Number of divergences: 0
# Estimated line: y = 0.6712x + 0.0646
# Estimated scatter (sigma): 0.5131
# True line: y = 0.6120x + 0.1200
# True scatter (sigma): 0.5000
#
# Estimated line: y = 0.6712x + 0.0633
# Estimated scatter (sigma): 0.5101
# True line: y = 0.6120x + 0.1200
# True scatter (sigma): 0.5000
# ([Array(1.205123, dtype=float32),
# ...

# %%
# One run
runner_with_uplims(nrepeats=1, nx=100, nuplims=20, parallel=False, start_i=0,  plot=False, previous_data_gen = False, marg=True)
# Out:
# Show results of each iteration: True
# RUN #0
# sample: 100%|██████████| 6000/6000 [00:08<00:00, 720.29it/s, 7 steps of size 6.19e-01. acc. prob=0.93]
#                 mean       std    median      5.0%     95.0%     n_eff     r_hat
#          A      0.67      0.05      0.67      0.60      0.76   1171.79      1.00
#          B      0.06      0.06      0.06     -0.03      0.16   1597.09      1.00
#   mu_gauss     -0.43      0.12     -0.43     -0.61     -0.22   1394.03      1.00
#        sig      0.51      0.04      0.51      0.45      0.59   1544.54      1.00
#    w_gauss      1.22      0.09      1.22      1.07      1.36   1259.83      1.00
#
# Number of divergences: 0
# Estimated line: y = 0.6712x + 0.0646
# Estimated scatter (sigma): 0.5131
# True line: y = 0.6120x + 0.1200
# True scatter (sigma): 0.5000
#
# Estimated line: y = 0.6712x + 0.0633
# Estimated scatter (sigma): 0.5101
# True line: y = 0.6120x + 0.1200
# True scatter (sigma): 0.5000
# ...

# %%
from utilities_general import *
_, _, _, _, _, _, _, _, true_vals = gen_synthetic_data(seed=0, plot=False)
slope_true, offset_true, mu_true, w_true, sig_true = true_vals

# %%
type(true_vals)
# Out:
# list

# %%
[list(true_vals)]*5
# Out:
# [[0.612, 0.12, -0.26670460907759524, 1.3956861244670145, 0.5],
#  [0.612, 0.12, -0.26670460907759524, 1.3956861244670145, 0.5],
#  [0.612, 0.12, -0.26670460907759524, 1.3956861244670145, 0.5],
#  [0.612, 0.12, -0.26670460907759524, 1.3956861244670145, 0.5],
#  [0.612, 0.12, -0.26670460907759524, 1.3956861244670145, 0.5]]

# %%
# One run 
print("Our method:")
run_linear_regression_marginalised_xt(i=0, plot=True,nx=10)
# Out:
# Our method:
# sample: 100%|██████████| 6000/6000 [00:09<00:00, 622.36it/s, 7 steps of size 5.47e-01. acc. prob=0.88]
#                 mean       std    median      5.0%     95.0%     n_eff     r_hat
#          A      0.64      0.23      0.64      0.28      0.95    583.70      1.00
#          B     -0.18      0.29     -0.17     -0.60      0.28    602.84      1.00
#   mu_gauss      0.03      0.55      0.04     -0.91      0.88    668.55      1.00
#        sig      0.76      0.37      0.68      0.32      1.18    263.00      1.01
#    w_gauss      1.60      0.44      1.53      0.93      2.23    508.11      1.00
#
# Number of divergences: 0
# Estimated line: y = 0.6367x + -0.1817
# Estimated scatter (sigma): 0.7624
# True line: y = 0.6120x + 0.1200
# True scatter (sigma): 0.5000
#
# Estimated line: y = 0.6383x + -0.1664
# Estimated scatter (sigma): 0.6770
# True line: y = 0.6120x + 0.1200
# True scatter (sigma): 0.5000
# ([Array(0.10850125, dtype=float32),
# ...
