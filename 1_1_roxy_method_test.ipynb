# %% [markdown]
# Notebook to test ROXY method (i.e. no uplims in the likelihood).

# %%
from utilities_single_reg_no_uplims import *
from utilities_general import *

# %% [markdown]
# # Test data generation

# %%
# Get the test data
xdet, ydet, xdet_err, ydet_err, xuplim, yuplim, xuplim_err, yuplim_err, true_params  = gen_synthetic_data_old(nx=100, nuplims=60, seed=0, plot=True)
# Out:
# 0.046395814582678364
# 0.975278192114649

# %%
# Get the test data
xdet, ydet, xdet_err, ydet_err, xuplim, yuplim, xuplim_err, yuplim_err, true_params   = gen_synthetic_data_old(nx=1000, nuplims=0, seed=0, plot=True)
# Out:
# -0.14416735226490232
# 0.988125632251971

# %%
# Get the test data
xdet, ydet, xdet_err, ydet_err, xuplim, yuplim, xuplim_err, yuplim_err , true_params  = gen_synthetic_data_old(nx=1000, nuplims=1, seed=0, plot=True)
# Out:
# -0.1424062904827346
# 0.9870492226439759

# %% [markdown]
# # ROXY method test

# %%
# Test with 1 run
runner_without_uplims(nrepeats=1, nx=100,  previous_data_gen = True)
# Out:
# RUN #0
# -0.03363094680568807
# 1.0255918438270308
# sample: 100%|██████████| 6000/6000 [00:06<00:00, 974.88it/s, 7 steps of size 6.48e-01. acc. prob=0.92]
#                 mean       std    median      5.0%     95.0%     n_eff     r_hat
#          A      0.61      0.02      0.61      0.57      0.65   1362.50      1.00
#          B      2.97      0.02      2.97      2.93      3.01   1510.67      1.00
#   mu_gauss     -0.03      0.11     -0.03     -0.20      0.14   1360.04      1.00
#        sig      0.20      0.02      0.20      0.17      0.23   1231.57      1.00
#    w_gauss      1.04      0.08      1.03      0.91      1.15   1588.83      1.00
#
# Number of divergences: 0
# (1000, 5)
# Estimated line: y = 0.6058x + 2.9686
# Estimated scatter (sigma): 0.1983
# True line: y = 0.6000x + 3.0000
# True scatter (sigma): 0.2000

# %%
# Test with 1 run, with another seed
runner_without_uplims(nrepeats=1, nx=100, start_seed=10,  previous_data_gen = True)
# Out:
# RUN #0
# -0.03363094680568807
# 1.0255918438270308
# sample: 100%|██████████| 6000/6000 [00:05<00:00, 1188.70it/s, 7 steps of size 6.48e-01. acc. prob=0.92]
#                 mean       std    median      5.0%     95.0%     n_eff     r_hat
#          A      0.61      0.02      0.61      0.57      0.65   1362.50      1.00
#          B      2.97      0.02      2.97      2.93      3.01   1510.67      1.00
#   mu_gauss     -0.03      0.11     -0.03     -0.20      0.14   1360.04      1.00
#        sig      0.20      0.02      0.20      0.17      0.23   1231.57      1.00
#    w_gauss      1.04      0.08      1.03      0.91      1.15   1588.83      1.00
#
# Number of divergences: 0
# (1000, 5)
# Estimated line: y = 0.6058x + 2.9686
# Estimated scatter (sigma): 0.1983
# True line: y = 0.6000x + 3.0000
# True scatter (sigma): 0.2000

# %%
# Test with many runs
runner_without_uplims(nrepeats=100, nx=100,  previous_data_gen = True)
# Out:
# RUN #0
# sample: 100%|██████████| 6000/6000 [00:08<00:00, 715.76it/s, 15 steps of size 1.54e-01. acc. prob=0.95]
# RUN #1
# sample: 100%|██████████| 6000/6000 [00:08<00:00, 700.10it/s, 15 steps of size 1.48e-01. acc. prob=0.93]
# RUN #2
# sample: 100%|██████████| 6000/6000 [00:07<00:00, 763.79it/s, 15 steps of size 1.91e-01. acc. prob=0.93]
# RUN #3
# sample: 100%|██████████| 6000/6000 [00:08<00:00, 742.70it/s, 15 steps of size 1.94e-01. acc. prob=0.92]
# RUN #4
# sample: 100%|██████████| 6000/6000 [00:08<00:00, 723.18it/s, 15 steps of size 1.64e-01. acc. prob=0.93]
# RUN #5
# sample: 100%|██████████| 6000/6000 [00:08<00:00, 737.66it/s, 15 steps of size 1.62e-01. acc. prob=0.93]
# RUN #6
# sample: 100%|██████████| 6000/6000 [00:08<00:00, 707.91it/s, 15 steps of size 1.77e-01. acc. prob=0.93]
# RUN #7
# sample: 100%|██████████| 6000/6000 [00:08<00:00, 700.83it/s, 31 steps of size 1.97e-01. acc. prob=0.90]
# RUN #8
# ...
